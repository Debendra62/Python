# %% [markdown]
# # Pie Chart ( discreate ) [x]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
employee=[1100,2400,3400,6000]
branch=[1000,2000,1400,1100]
plt.pie(branch)
# Out:
# ([<matplotlib.patches.Wedge at 0x1775ef0fa00>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, ''),
#   Text(-0.7203468639465174, 0.8313244827396927, ''),
#   Text(-0.5133339694293887, -0.9728762695378419, ''),
#   Text(0.8899187482945414, -0.6465637025335375, '')])

# %%
plt.pie(employee)
# Out:
# ([<matplotlib.patches.Wedge at 0x1775ef2e5e0>,
# ...
#  [Text(1.060765362537315, 0.2911646366595345, ''),
#   Text(0.47899536043043967, 0.9902340353098925, ''),
#   Text(-0.9023458665721927, 0.6291040749193083, ''),
#   Text(0.120308437539095, -1.0934010608449682, '')])

# %%
mylabel=["Google","Amazon","Apple","Netflix"]
plt.pie(employee,startangle=90,labels=mylabel)
# Out:
# ([<matplotlib.patches.Wedge at 0x1775ef71d60>,
# ...
#  [Text(-0.2911646366595344, 1.060765362537315, 'Google'),
#   Text(-0.9902340353098924, 0.47899536043043994, 'Amazon'),
#   Text(-0.629104074919308, -0.902345866572193, 'Apple'),
#   Text(1.0934010608449682, 0.12030843753909494, 'Netflix')])

# %%
plt.pie(employee,startangle=90,labels=mylabel,explode=[0,0.2,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1775f07bf70>,
# ...
#  [Text(-0.2911646366595344, 1.060765362537315, 'Google'),
#   Text(-1.1702765871844183, 0.5660854259632472, 'Amazon'),
#   Text(-0.629104074919308, -0.902345866572193, 'Apple'),
#   Text(1.0934010608449682, 0.12030843753909494, 'Netflix')])
